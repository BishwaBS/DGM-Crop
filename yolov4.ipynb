# %% [markdown]
# **Mounting** the drive

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')

# %%
#set the cloned dir as current working dir
# !git clone https://github.com/BishwaBS/DGM-Crop.git
os.chdir("DGM-Crop")

# %%
# !git clone https://github.com/AlexeyAB/darknet.git

# %%
import os
os.chdir("DGM-Crop/darknet")
# !sudo chmod +x darknet
# !./darknet
# Out:
# usage: ./darknet <function>

# %%
#download model weights
# !mkdir yolo_weight 

# !wget -p /yolo_weight https://drive.google.com/file/d/1-PJRCerxLwV-zZeX4eqiprLd864vPKN-/view?usp=sharing

# %% [markdown]
# Generating path texts

# %% [markdown]
# ### **Testing the model on single image**

# %%
# define helper functions
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
#prediction on single image (multi_model)
# !./darknet detector test data/multi_model/obj.data cfg/yolov4-obj.cfg path/to/modelweight path/to/testimage -thresh 0.5
imShow("predictions.jpg")
